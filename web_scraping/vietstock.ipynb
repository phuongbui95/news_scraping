# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://vietstock.vn/tai-chinh/ngan-hang.htm"

# Fetch page
response = requests.get(url)
response.raise_for_status()

# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")

# Container
paging = soup.find("div", id="paging")

articles_data = []

if paging:
    articles = paging.find_all("article", class_="item-news")

    for article in articles:
        # ---------- TITLE + LINK ----------
        title_tag = article.find("h3", class_="title-news")
        title = link = None

        if title_tag and title_tag.a:
            title = title_tag.a.get_text(strip=True)
            link = title_tag.a.get("href")

        # ---------- AUTHOR ----------
        author = None
        author_tag = article.select_one("p.meta-news a.name-author")
        if author_tag:
            author = author_tag.get_text(strip=True)

        articles_data.append({
            "title": title,
            "author": author,
            "link": link
        })

# ---------- OUTPUT ----------
for i, item in enumerate(articles_data, 1):
    print(f"Item {i}")
    print("Title :", item["title"])
    print("Author:", item["author"])
    print("Link  :", item["link"])
    print("-" * 50)
# Out:
# Name: requests
# Version: 2.32.5
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: /home/phuongbui/news_scraping/web_scraping/.venv/lib/python3.10/site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
